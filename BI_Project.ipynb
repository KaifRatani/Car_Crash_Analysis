# %% [markdown]
# <a href="https://colab.research.google.com/github/KaifRatani/Car_Crash_Analysis/blob/main/BI_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Finding the missing values for this dataset
#
#
# Vehicle First Impact Location
#
# Vehicle Body Type
#
# Vehicle Movement
#
# Vehicle Going Dir
#
# Speed Limit
#
# Driverless Vehicle - not useful
#
# Parked Vehicle
#
# Vehicle Year
#
# Vehicle Make
#
# Vehicle Model
#
# Latitude
#
# Longitude
#
# Location

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Crash_Reporting_-_Drivers_Data_20250307.csv")
bool_series = pd.isnull(df["Vehicle Model"])
missing_vm_data = df[bool_series]
missing_vm_data
# Out:
# <ipython-input-20-22d583aae403>:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Crash_Reporting_-_Drivers_Data_20250307.csv")
#       Report Number Local Case Number                Agency Name  \
# 3237    MCP27470011          15007153   Montgomery County Police
# 4750    MCP2637000P          15036042                 MONTGOMERY
# 4949     EJ7894003L         230060480  Gaithersburg Police Depar
# 6778     DM85020006         210051438  Takoma Park Police Depart
# 7391     EJ7898000P         230048689  Gaithersburg Police Depar
# 8413    MCP3312003Q         230035229   Montgomery County Police
# 13080   MCP2916002S         180053644   Montgomery County Police
# 13859   MCP2805003W         200025939   Montgomery County Police
# 24342   MCP2702000Z          15040995                 MONTGOMERY
# 29228   MCP30900018         180043017   Montgomery County Police
# ...

# %%
bool_series = pd.isnull(df["Parked Vehicle"])
missing_vm_data = df[bool_series]
missing_vm_data
# Out:
#       Report Number Local Case Number               Agency Name  \
# 87761   MCP2840000Q          16027616  Montgomery County Police
#
#       ACRS Report Type         Crash Date/Time Route Type        Road Name  \
# 87761     Injury Crash  06/02/2016 04:00:00 PM     County  INDUSTRIAL PKWY
#
#       Cross-Street Name Off-Road Description Municipality  ...  \
# 87761     COLUMBIA PIKE                  NaN          NaN  ...
#
#       Vehicle Going Dir Speed Limit Driverless Vehicle Parked Vehicle  \
# 87761               NaN         NaN                NaN            NaN
#
#       Vehicle Year Vehicle Make Vehicle Model Latitude Longitude Location
# 87761          NaN          NaN           NaN      NaN       NaN      NaN
#
# [1 rows x 39 columns]
